# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('crest_r')
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('interviewquestions.csv')

# %%
def show_df(df):

    print('shape'.center(30,'_'))
    display(df.shape)

    print('head'.center(30,'_'))
    display(df.head())

    print('tail'.center(30,'_'))
    display(df.tail())

    print('info'.center(30,'_')+'\n')
    display(df.info())

    print('describe'.center(30,'_'))
    display(df.describe().T)

show_df(df)
# Out:
# ____________shape_____________
# (570, 5)
# _____________head_____________
#    id                                           question  \
# 0   0  Why is Flutter preferred over other mobile app...
# 1   1                                   What is Flutter?
# 2   2          What are packages and plugins in Flutter?
# 3   3               What are the limitations of Flutter?
# 4   4  Why does it generally take a long time to deve...
#
#                                               answer difficulty    track
# 0  Flutter is a free and open-source mobile UI fr...       easy  flutter
# 1  Flutter is a UI-based tool for creating mobile...       easy  flutter
# 2  A package is a set of classes, interfaces, and...       easy  flutter
# 3  Since Flutter is still a relatively new tool, ...       easy  flutter
# 4  Because Flutter generates a device-specific IP...       easy  flutter
# _____________tail_____________
# ...

# %%
def check(df):
    print('Number of null values'.center(30,'_'))
    print(df.isnull().sum())
    print(50*'_')
    print('\n'+'Number of duplicated values'.center(30,'_')+'\n')
    print(f'--------{df.duplicated().sum()}')
check(df)
# Out:
# ____Number of null values_____
# id             0
# question       0
# answer        55
# difficulty     0
# track          0
# dtype: int64
# __________________________________________________
#
# _Number of duplicated values__
#
# --------0

# %%
x = sns.countplot(x = "track", data=df , hue= 'difficulty')

# %%
general = df[df['track'] == 'general']

# %%
general.to_csv('general.csv')

# %%
def check(df):
    print('Number of null values'.center(30,'_'))
    print(df.isnull().sum())
    print(50*'_')
    print('\n'+'Number of duplicated values'.center(30,'_')+'\n')
    print(f'--------{df.duplicated().sum()}')
check(df)
# Out:
# ____Number of null values_____
# id             0
# question       0
# answer        55
# difficulty     0
# track          0
# dtype: int64
# __________________________________________________
#
# _Number of duplicated values__
#
# --------0

# %%
df.dropna(inplace=True)

# %%
def check(df):
    print('Number of null values'.center(30,'_'))
    print(df.isnull().sum())
    print(50*'_')
    print('\n'+'Number of duplicated values'.center(30,'_')+'\n')
    print(f'--------{df.duplicated().sum()}')
check(df)
# Out:
# ____Number of null values_____
# id            0
# question      0
# answer        0
# difficulty    0
# track         0
# dtype: int64
# __________________________________________________
#
# _Number of duplicated values__
#
# --------0

# %%
plt.figure(figsize=(12, 8))
ax = sns.countplot(x = "track", data=df , hue= 'difficulty')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.legend(title='Difficulty', loc='upper right')
plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Label Distribution')

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 15), textcoords='offset points')

plt.show()

# %%
df['text_length'] = df['answer'].apply(lambda x: len(x))
sns.boxplot(data=df, y='text_length')
plt.ylabel('Text Length')
plt.title('Box Plot of Text Length')
plt.show()

# %%
df['text_length'] = df['answer'].apply(lambda x: len(x))
tracks = df['track'].unique()
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x="track", y="text_length", hue="difficulty")
plt.title('Box Plot of Text Length by Track and Difficulty')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
technical= df.to_csv('technical.csv')
